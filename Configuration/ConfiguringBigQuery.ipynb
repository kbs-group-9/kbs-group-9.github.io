# %%
# %load_ext google.cloud.bigquery
# Out:
# The google.cloud.bigquery extension is already loaded. To reload it, use:
#   %reload_ext google.cloud.bigquery

# %%
# %%bigquery us_dataframe
# select * from `kbs-2020.usaccidents.accidents` limit 10

# %%
# %%bigquery
# select * from `kbs-2020.usaccidents.accidents` limit 10
# Out:
#           ID    Source    TMC  Severity                Start_Time  \
# 0     A-1732  MapQuest  343.0         2 2016-06-30 00:14:25+00:00
# 1     A-2567  MapQuest  222.0         3 2016-07-08 21:45:35+00:00
# 2     A-4550  MapQuest  206.0         2 2016-07-28 12:35:23+00:00
# 3    A-20612  MapQuest  343.0         2 2016-09-16 21:11:52+00:00
# 4    A-24273  MapQuest  247.0         2 2016-10-13 13:46:38+00:00
# 5    A-25865  MapQuest  222.0         2 2016-08-04 15:25:40+00:00
# 6    A-27514  MapQuest  247.0         3 2016-08-16 11:51:01+00:00
# 7    A-27853  MapQuest  222.0         2 2016-08-18 18:42:03+00:00
# 8    A-30229  MapQuest  222.0         2 2016-09-06 20:53:44+00:00
# 9  A-1176585  MapQuest  222.0         3 2019-01-17 08:39:01+00:00
#
#                    End_Time  Start_Lat   Start_Lng End_Lat End_Lng  ...  \
# 0 2016-06-30 00:44:25+00:00  38.478760 -121.945404    None    None  ...
# 1 2016-07-08 23:45:35+00:00  38.554710 -121.687317    None    None  ...
# ...

# %%
# %matplotlib inline

# %%
us_dataframe.plot(kind='bar', x='Severity', y='Temperature_F_');
