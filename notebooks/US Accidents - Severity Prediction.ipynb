# %% [markdown]
# # US Accidents - Severity Prediction

# %% [markdown]
# ## Team Members
# - Aditya Kamble
# - Sidharth Panda

# %% [markdown]
# ## Import Dependencies

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
# Out:
# /usr/local/lib/python3.5/site-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d

# %%
from pyspark.ml import Pipeline
from pyspark.ml.regression import RandomForestRegressor
from pyspark.ml.feature import VectorIndexer
from pyspark.ml.evaluation import RegressionEvaluator
from pyspark.context import SparkContext
from pyspark.sql.session import SparkSession
from pyspark.ml.feature import OneHotEncoderEstimator, StringIndexer, VectorAssembler
from pyspark.ml.classification import RandomForestClassifier, DecisionTreeClassifier, LogisticRegression
from pyspark.ml.evaluation import BinaryClassificationEvaluator, MulticlassClassificationEvaluator

# %% [markdown]
# ## Data Preparation

# %%
# %%bigquery data_df
# select * from `kbs-2020.usaccidents.accidents`

# %%
data_df.shape
# Out:
# (2974335, 49)

# %%
data_df.head()
# Out:
#           ID    Source    TMC  Severity                Start_Time  \
# 0     A-3418  MapQuest  222.0         2 2016-07-18 17:05:24+00:00
# 1    A-25968  MapQuest  247.0         2 2016-08-05 12:42:34+00:00
# 2    A-28018  MapQuest  222.0         3 2016-08-19 20:53:29+00:00
# 3    A-38797  MapQuest  248.0         2 2016-05-17 18:25:22+00:00
# 4  A-1180743  MapQuest  246.0         3 2019-01-19 12:45:07+00:00
#
#                    End_Time  Start_Lat   Start_Lng End_Lat End_Lng  ...  \
# 0 2016-07-18 18:20:24+00:00  38.932369 -121.090813    None    None  ...
# 1 2016-08-05 13:27:34+00:00  37.788002 -122.393623    None    None  ...
# 2 2016-08-19 22:08:29+00:00  38.773979 -121.241997    None    None  ...
# 3 2016-05-17 18:55:22+00:00  37.800373 -122.447121    None    None  ...
# 4 2019-01-19 13:29:26+00:00  33.941284  -84.504784    None    None  ...
#
#    Roundabout Station   Stop Traffic_Calming Traffic_Signal Turning_Loop  \
# 0       False   False  False           False           True        False
# 1       False   False  False           False           True        False
# 2       False   False  False           False          False        False
# 3       False   False  False           False           True        False
# 4       False   False  False           False          False        False
#
#   Sunrise_Sunset Civil_Twilight Nautical_Twilight Astronomical_Twilight
# 0            Day            Day               Day                   Day
# 1            Day            Day               Day                   Day
# 2          Night          Night               Day                   Day
# 3            Day            Day               Day                   Day
# 4            Day            Day               Day                   Day
#
# [5 rows x 49 columns]

# %%
data_df.columns
# Out:
# Index(['ID', 'Source', 'TMC', 'Severity', 'Start_Time', 'End_Time',
#        'Start_Lat', 'Start_Lng', 'End_Lat', 'End_Lng', 'Distance_mi_',
#        'Description', 'Number', 'Street', 'Side', 'City', 'County', 'State',
#        'Zipcode', 'Country', 'Timezone', 'Airport_Code', 'Weather_Timestamp',
#        'Temperature_F_', 'Wind_Chill_F_', 'Humidity___', 'Pressure_in_',
#        'Visibility_mi_', 'Wind_Direction', 'Wind_Speed_mph_',
#        'Precipitation_in_', 'Weather_Condition', 'Amenity', 'Bump', 'Crossing',
#        'Give_Way', 'Junction', 'No_Exit', 'Railway', 'Roundabout', 'Station',
#        'Stop', 'Traffic_Calming', 'Traffic_Signal', 'Turning_Loop',
#        'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
data_df.describe()
# Out:
#                 TMC      Severity     Start_Lat     Start_Lng  Distance_mi_  \
# count  2.246264e+06  2.974335e+06  2.974335e+06  2.974335e+06  2.974335e+06
# mean   2.078316e+02  2.360190e+00  3.649361e+01 -9.542625e+01  2.855654e-01
# std    2.032959e+01  5.414733e-01  4.918849e+00  1.721881e+01  1.548392e+00
# min    2.000000e+02  1.000000e+00  2.455527e+01 -1.246238e+02  0.000000e+00
# 25%    2.010000e+02  2.000000e+00  3.355040e+01 -1.172920e+02  0.000000e+00
# 50%    2.010000e+02  2.000000e+00  3.584969e+01 -9.025083e+01  0.000000e+00
# 75%    2.010000e+02  3.000000e+00  4.037026e+01 -8.091891e+01  1.000000e-02
# max    4.060000e+02  4.000000e+00  4.900220e+01 -6.711317e+01  3.336300e+02
#
#              Number  Temperature_F_  Wind_Chill_F_   Humidity___  \
# count  1.056730e+06    2.918272e+06   1.121712e+06  2.915162e+06
# mean   5.837004e+03    6.235120e+01   5.132685e+01  6.540542e+01
# std    1.515928e+04    1.878855e+01   2.519127e+01  2.255676e+01
# min    0.000000e+00   -7.780000e+01  -6.590000e+01  1.000000e+00
# 25%    8.370000e+02    5.000000e+01   3.200000e+01  4.900000e+01
# 50%    2.717000e+03    6.440000e+01   5.400000e+01  6.700000e+01
# 75%    7.000000e+03    7.600000e+01   7.300000e+01  8.400000e+01
# max    9.999997e+06    1.706000e+02   1.150000e+02  1.000000e+02
#
#        Pressure_in_  Visibility_mi_  Wind_Speed_mph_  Precipitation_in_
# count  2.926193e+06    2.908644e+06     2.533495e+06      975977.000000
# mean   2.983190e+01    9.150770e+00     8.298064e+00           0.020495
# std    7.213808e-01    2.892114e+00     5.138546e+00           0.235770
# min    0.000000e+00    0.000000e+00     0.000000e+00           0.000000
# 25%    2.982000e+01    1.000000e+01     4.600000e+00           0.000000
# 50%    2.998000e+01    1.000000e+01     7.000000e+00           0.000000
# 75%    3.011000e+01    1.000000e+01     1.040000e+01           0.000000
# max    3.304000e+01    1.400000e+02     8.228000e+02          25.000000

# %%
data_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2974335 entries, 0 to 2974334
# Data columns (total 49 columns):
# ID                       object
# Source                   object
# TMC                      float64
# Severity                 int64
# Start_Time               datetime64[ns, UTC]
# End_Time                 datetime64[ns, UTC]
# Start_Lat                float64
# Start_Lng                float64
# End_Lat                  object
# End_Lng                  object
# Distance_mi_             float64
# Description              object
# Number                   float64
# Street                   object
# Side                     object
# City                     object
# County                   object
# State                    object
# Zipcode                  object
# Country                  object
# Timezone                 object
# Airport_Code             object
# Weather_Timestamp        datetime64[ns, UTC]
# Temperature_F_           float64
# Wind_Chill_F_            float64
# Humidity___              float64
# Pressure_in_             float64
# Visibility_mi_           float64
# Wind_Direction           object
# Wind_Speed_mph_          float64
# Precipitation_in_        float64
# Weather_Condition        object
# Amenity                  bool
# Bump                     bool
# Crossing                 bool
# Give_Way                 bool
# Junction                 bool
# No_Exit                  bool
# Railway                  bool
# Roundabout               bool
# Station                  bool
# Stop                     bool
# Traffic_Calming          bool
# Traffic_Signal           bool
# Turning_Loop             bool
# Sunrise_Sunset           object
# Civil_Twilight           object
# Nautical_Twilight        object
# Astronomical_Twilight    object
# dtypes: bool(13), datetime64[ns, UTC](3), float64(12), int64(1), object(20)
# memory usage: 853.8+ MB

# %% [markdown]
# ## Feature Preprocessing

# %%
data_df['Start_Time'] = pd.to_datetime(data_df['Start_Time'], errors='coerce')
data_df['End_Time'] = pd.to_datetime(data_df['End_Time'], errors='coerce')

# %%
# Extract year, month, day, hour and weekday

data_df['Year'] = data_df['Start_Time'].dt.year
data_df['Month'] = data_df['Start_Time'].dt.strftime('%b')
data_df['Day'] = data_df['Start_Time'].dt.day
data_df['Hour'] = data_df['Start_Time'].dt.hour
data_df['Weekday'] = data_df['Start_Time'].dt.strftime('%a')

# %% [markdown]
# **Time in the unit of minutes for each accident**

# %%
time_duration = 'Time_Duration_Min'

# %%
data_df[time_duration] = round((data_df['End_Time'] - data_df['Start_Time'])/np.timedelta64(1,'m'))

# %%
data_df.head()
# Out:
#           ID    Source    TMC  Severity                Start_Time  \
# 0     A-3418  MapQuest  222.0         2 2016-07-18 17:05:24+00:00
# 1    A-25968  MapQuest  247.0         2 2016-08-05 12:42:34+00:00
# 2    A-28018  MapQuest  222.0         3 2016-08-19 20:53:29+00:00
# 3    A-38797  MapQuest  248.0         2 2016-05-17 18:25:22+00:00
# 4  A-1180743  MapQuest  246.0         3 2019-01-19 12:45:07+00:00
#
#                    End_Time  Start_Lat   Start_Lng End_Lat End_Lng  ...  \
# 0 2016-07-18 18:20:24+00:00  38.932369 -121.090813    None    None  ...
# 1 2016-08-05 13:27:34+00:00  37.788002 -122.393623    None    None  ...
# 2 2016-08-19 22:08:29+00:00  38.773979 -121.241997    None    None  ...
# 3 2016-05-17 18:55:22+00:00  37.800373 -122.447121    None    None  ...
# 4 2019-01-19 13:29:26+00:00  33.941284  -84.504784    None    None  ...
#
#    Sunrise_Sunset Civil_Twilight  Nautical_Twilight Astronomical_Twilight  \
# 0             Day            Day                Day                   Day
# 1             Day            Day                Day                   Day
# 2           Night          Night                Day                   Day
# 3             Day            Day                Day                   Day
# 4             Day            Day                Day                   Day
#
#    Year Month Day Hour Weekday Time_Duration_Min
# 0  2016   Jul  18   17     Mon              75.0
# 1  2016   Aug   5   12     Fri              45.0
# 2  2016   Aug  19   20     Fri              75.0
# 3  2016   May  17   18     Tue              30.0
# 4  2019   Jan  19   12     Sat              44.0
#
# [5 rows x 55 columns]

# %%
data_df.tail()
# Out:
#                 ID    Source    TMC  Severity                Start_Time  \
# 2974330   A-643009  MapQuest  245.0         3 2019-11-09 17:57:49+00:00
# 2974331   A-825446  MapQuest  245.0         3 2019-07-28 17:02:02+00:00
# 2974332  A-1668519  MapQuest  245.0         3 2018-05-19 15:49:07+00:00
# 2974333  A-1966071  MapQuest  245.0         3 2017-12-15 19:02:43+00:00
# 2974334  A-2094111  MapQuest  245.0         3 2017-10-22 17:25:57+00:00
#
#                          End_Time  Start_Lat  Start_Lng End_Lat End_Lng  ...  \
# 2974330 2019-11-09 20:05:14+00:00  30.439508 -91.195831    None    None  ...
# 2974331 2019-07-28 17:30:23+00:00  30.484991 -91.166161    None    None  ...
# 2974332 2018-05-19 16:48:41+00:00  30.499462 -91.159531    None    None  ...
# 2974333 2017-12-15 19:32:28+00:00  30.442533 -91.007462    None    None  ...
# 2974334 2017-10-22 17:55:38+00:00  30.422909 -91.139572    None    None  ...
#
#          Sunrise_Sunset Civil_Twilight  Nautical_Twilight  \
# 2974330           Night          Night                Day
# 2974331             Day            Day                Day
# 2974332             Day            Day                Day
# 2974333           Night          Night              Night
# 2974334             Day            Day                Day
#
#         Astronomical_Twilight  Year Month Day Hour Weekday Time_Duration_Min
# 2974330                   Day  2019   Nov   9   17     Sat             127.0
# 2974331                   Day  2019   Jul  28   17     Sun              28.0
# 2974332                   Day  2018   May  19   15     Sat              60.0
# 2974333                 Night  2017   Dec  15   19     Fri              30.0
# 2974334                   Day  2017   Oct  22   17     Sun              30.0
#
# [5 rows x 55 columns]

# %% [markdown]
# ### Remove Entries with negative time duration

# %%
neg_outliers = data_df[time_duration] <= 0
data_df[neg_outliers] = np.nan
data_df.dropna(subset=[time_duration],axis=0,inplace=True)

# %%
features_imp = ['TMC',
                'Start_Lng',
                'Start_Lat',
                'Distance_mi_',
                'Temperature_F_',
                'Humidity___',
                'Pressure_in_',
                'Hour',
                'State',
                'Severity',
                'Time_Duration_Min']

# %%
data_df_ml = data_df[features_imp].copy()

# %%
data_df_ml.dropna(subset=data_df_ml.columns[data_df_ml.isnull().mean()!=0], how='any', axis=0, inplace=True)

# %%
data_df_ml.head()
# Out:
#      TMC   Start_Lng  Start_Lat  Distance_mi_  Temperature_F_  Humidity___  \
# 0  222.0 -121.090813  38.932369           0.0            80.6         26.0
# 1  247.0 -122.393623  37.788002           0.0            64.9         70.0
# 2  222.0 -121.241997  38.773979           0.0            80.6         37.0
# 3  248.0 -122.447121  37.800373           0.0            77.0         74.0
# 4  246.0  -84.504784  33.941284           0.0            59.2        100.0
#
#    Pressure_in_  Hour State  Severity  Time_Duration_Min
# 0         30.05  17.0    CA       2.0               75.0
# 1         29.94  12.0    CA       2.0               45.0
# 2         29.80  20.0    CA       3.0               75.0
# 3         29.89  18.0    CA       2.0               30.0
# 4         29.77  12.0    GA       3.0               44.0

# %% [markdown]
# ## Modelling

# %% [markdown]
# Note - Processing all states at a time is resource heavy using normal data preprocessing. Using PySpark would resolve the issue

# %%
target = 'Severity'

# %%
data_df_ml_en = pd.get_dummies(data_df_ml, drop_first=True)

# %%
data_df_ml_en.to_csv('data-processed/us_accidents_dec19.csv', index=False)

# %%
sparkContext = SparkContext.getOrCreate()
spark = SparkSession(sparkContext)

# %%
data_df = spark.read.csv('data-processed/us_accidents_dec19.csv', header = True, inferSchema = True)
data_df.printSchema()
# Out:
# root
#  |-- TMC: double (nullable = true)
#  |-- Start_Lng: double (nullable = true)
#  |-- Start_Lat: double (nullable = true)
#  |-- Distance_mi_: double (nullable = true)
#  |-- Temperature_F_: double (nullable = true)
#  |-- Humidity___: double (nullable = true)
#  |-- Pressure_in_: double (nullable = true)
#  |-- Hour: double (nullable = true)
#  |-- Severity: double (nullable = true)
#  |-- Time_Duration_Min: double (nullable = true)
#  |-- State_AR: integer (nullable = true)
#  |-- State_AZ: integer (nullable = true)
#  |-- State_CA: integer (nullable = true)
#  |-- State_CO: integer (nullable = true)
#  |-- State_CT: integer (nullable = true)
#  |-- State_DC: integer (nullable = true)
#  |-- State_DE: integer (nullable = true)
#  |-- State_FL: integer (nullable = true)
#  |-- State_GA: integer (nullable = true)
#  |-- State_IA: integer (nullable = true)
#  |-- State_ID: integer (nullable = true)
#  |-- State_IL: integer (nullable = true)
#  |-- State_IN: integer (nullable = true)
#  |-- State_KS: integer (nullable = true)
#  |-- State_KY: integer (nullable = true)
#  |-- State_LA: integer (nullable = true)
#  |-- State_MA: integer (nullable = true)
#  |-- State_MD: integer (nullable = true)
#  |-- State_ME: integer (nullable = true)
#  |-- State_MI: integer (nullable = true)
#  |-- State_MN: integer (nullable = true)
#  |-- State_MO: integer (nullable = true)
#  |-- State_MS: integer (nullable = true)
#  |-- State_MT: integer (nullable = true)
#  |-- State_NC: integer (nullable = true)
#  |-- State_ND: integer (nullable = true)
#  |-- State_NE: integer (nullable = true)
#  |-- State_NH: integer (nullable = true)
#  |-- State_NJ: integer (nullable = true)
#  |-- State_NM: integer (nullable = true)
#  |-- State_NV: integer (nullable = true)
#  |-- State_NY: integer (nullable = true)
#  |-- State_OH: integer (nullable = true)
#  |-- State_OK: integer (nullable = true)
#  |-- State_OR: integer (nullable = true)
#  |-- State_PA: integer (nullable = true)
#  |-- State_RI: integer (nullable = true)
#  |-- State_SC: integer (nullable = true)
#  |-- State_SD: integer (nullable = true)
#  |-- State_TN: integer (nullable = true)
#  |-- State_TX: integer (nullable = true)
#  |-- State_UT: integer (nullable = true)
#  |-- State_VA: integer (nullable = true)
#  |-- State_VT: integer (nullable = true)
#  |-- State_WA: integer (nullable = true)
#  |-- State_WI: integer (nullable = true)
#  |-- State_WV: integer (nullable = true)
#  |-- State_WY: integer (nullable = true)

# %%
input_features = data_df.columns
input_features.remove('Severity')

# %%
assembler = VectorAssembler(inputCols = input_features , outputCol = 'features')

# %%
final_df = assembler.transform(data_df)

# %%
train, test = final_df.randomSplit([0.7, 0.3])

# %%
random_forest_classifier = RandomForestClassifier(labelCol = 'Severity', featuresCol = 'features')

# %%
decision_tree_classifier = DecisionTreeClassifier(labelCol = 'Severity', featuresCol = 'features')

# %%
rf_model = random_forest_classifier.fit(train)

# %%
rf_predictions = rf_model.transform(test)

# %%
dt_model = decision_tree_classifier.fit(train)

# %%
dt_predictions = dt_model.transform(test)

# %%
multi_evaluator = MulticlassClassificationEvaluator(labelCol = 'Severity', metricName = 'accuracy')

# %%
logistic_regression = LogisticRegression(labelCol = 'Severity', featuresCol = 'features')

# %%
lr_model = logistic_regression.fit(train)

# %%
lr_predictions = lr_model.transform(test)

# %%
print('Decision Tree Accuracy:', multi_evaluator.evaluate(dt_predictions))
print('Random Forest Accuracy:', multi_evaluator.evaluate(rf_predictions))
print('Logistic Regression:', multi_evaluator.evaluate(lr_predictions))
# Out:
# Decision Tree Accuracy: 0.6929468555172205
# Random Forest Accuracy: 0.6657784032443557
# Logistic Regression: 0.6859224623206828
